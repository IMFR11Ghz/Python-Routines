# %%
import numpy as np
import pylab as pl
import math
import matplotlib as mpl
from matplotlib.ticker import MultipleLocator
import matplotlib.pyplot as plt
import matplotlib.cbook as cbook
import serial

# %%
from IPython.display import Image
Image(filename='/home/alfazoom/imfr-hal/python/IMFR11GHz/Logotipo_IMFR11GHz.png')

# %%
# Velocidad de la Luz [m/s]
C = 299792458
# Frecuencia [Hz]
nu = 1.10e+10
# Longitud de Onda [mm]
Lambda = (C/nu)*1000
Lambda
# Out:
# 27.25385981818182

# %%
B = np.array([940, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300, 2400, 2500, 2600, 2700, 2800, 2900])
#print B
B_lambda = B / Lambda
print B_lambda
# Out:
# [  34.49052744   40.36125552   44.03046057   47.69966561   51.36887066
#    55.03807571   58.70728075   62.3764858    66.04569085   69.7148959
#    73.38410094   77.05330599   80.72251104   84.39171609   88.06092113
#    91.73012618   95.39933123   99.06853627  102.73774132  106.40694637]

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B940.log')
mpl.rcParams['figure.figsize'] = [15, 5]

fig = plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4')
pl.xlim(30,160)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.06,0.20))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 940 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B940.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B940.log')
mpl.rcParams['figure.figsize'] = [15, 5]

figg = plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(126,130)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.06,0.20))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 940 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B940-Z3.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
#Sample_1 at 111.5 segundos
B940_Pmax_1 = 0.182999998
B940_Pmin_1 = 0.088875003
B940_Vo1 = (B940_Pmax_1-B940_Pmin_1)/(B940_Pmax_1+B940_Pmin_1)

#Sample_2 at 86 segundos
B940_Pmax_2 = 0.193124995
B940_Pmin_2 = 0.085124999
B940_Vo2 = (B940_Pmax_2-B940_Pmin_2)/(B940_Pmax_2+B940_Pmin_2)

#Sample_3 at 128.5 segundos
B940_Pmax_3 = 0.186562508
B940_Pmin_3 = 0.085500002
B940_Vo3 = (B940_Pmax_3-B940_Pmin_3)/(B940_Pmax_3+B940_Pmin_3)

print("Visibilidad B940_vo1 =",B940_Vo1)
print("Visibilidad B940_vo2 =",B940_Vo2)
print("Visibilidad B940_vo3 =",B940_Vo3)

#Valor Promedio
B940_Vo = (B940_Vo1+B940_Vo2+B940_Vo3)/3
print("Visibilidad B940_Vo =",B940_Vo)
print("ok Baseline 940mm")
# Out:
# ('Visibilidad B940_vo1 =', 0.34620687688751495)
# ('Visibilidad B940_vo2 =', 0.3881401557191048)
# ('Visibilidad B940_vo3 =', 0.37146796153575146)
# ('Visibilidad B940_Vo =', 0.36860499804745706)
# ok Baseline 940mm

# %%
sigma_940=math.sqrt(((((B940_Vo1-B940_Vo)**2+(B940_Vo2-B940_Vo)**2+(B940_Vo3-B940_Vo)**2))/2))
sigma_940
# Out:
# 0.021112730480528703

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B1100.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(12,100)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.05,0.214))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 1100 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B1100.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B1100.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(72.5,73.5)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.05,0.09))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 1100 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B1100-Z3.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
#Sample_1 at 69 segundos
B1100_Pmax_1 = 0.0778125
B1100_Pmin_1 = 0.064125001
B1100_Vo1 = (B1100_Pmax_1-B1100_Pmin_1)/(B1100_Pmax_1+B1100_Pmin_1)

#Sample_2 at 51.3 segundos
B1100_Pmax_2 = 0.081187502
B1100_Pmin_2 = 0.066375002
B1100_Vo2 = (B1100_Pmax_2-B1100_Pmin_2)/(B1100_Pmax_2+B1100_Pmin_2)

#Sample_3 at 73 segundos
B1100_Pmax_3 = 0.077624999
B1100_Pmin_3 = 0.067500003
B1100_Vo3 = (B1100_Pmax_3-B1100_Pmin_3)/(B1100_Pmax_3+B1100_Pmin_3)

print("Visibilidad B1100_vo1 =",B1100_Vo1)
print("Visibilidad B1100_vo2 =",B1100_Vo2)
print("Visibilidad B1100_vo3 =",B1100_Vo3)

#Valor Promedio
B1100_Vo = (B1100_Vo1+B1100_Vo2+B1100_Vo3)/3
print("Visibilidad B1100_Vo =",B1100_Vo)
print("ok Baseline 1100mm")
# Out:
# ('Visibilidad B1100_vo1 =', 0.0964332815751068)
# ('Visibilidad B1100_vo2 =', 0.10038119168809981)
# ('Visibilidad B1100_vo3 =', 0.06976741333653864)
# ('Visibilidad B1100_Vo =', 0.08886062886658175)
# ok Baseline 1100mm

# %%
sigma_1100=math.sqrt(((((B1100_Vo1-B1100_Vo)**2+(B1100_Vo2-B1100_Vo)**2+(B1100_Vo3-B1100_Vo)**2))/2))
sigma_1100
# Out:
# 0.016652617152345082

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B1200.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(18,83)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.05,0.16))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 1200 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B1200.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B1200.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(54,55)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.05,0.095))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 1200 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B1200-Z3.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
#Sample_1 at 59.43 segundos
B1200_Pmax_1 = 0.086437501
B1200_Pmin_1 = 0.066937499
B1200_Vo1 = (B1200_Pmax_1-B1200_Pmin_1)/(B1200_Pmax_1+B1200_Pmin_1)

#Sample_2 at 62.76 segundos
B1200_Pmax_2 = 0.086625002
B1200_Pmin_2 = 0.064687498
B1200_Vo2 = (B1200_Pmax_2-B1200_Pmin_2)/(B1200_Pmax_2+B1200_Pmin_2)

#Sample_3 at 54.53 segundos
B1200_Pmax_3 = 0.083812498
B1200_Pmin_3 = 0.067874998
B1200_Vo3 = (B1200_Pmax_3-B1200_Pmin_3)/(B1200_Pmax_3+B1200_Pmin_3)

print("Visibilidad B1200_vo1 =",B1200_Vo1)
print("Visibilidad B1200_vo2 =",B1200_Vo2)
print("Visibilidad B1200_vo3 =",B1200_Vo3)

#Valor Promedio
B1200_Vo = (B1200_Vo1+B1200_Vo2+B1200_Vo3)/3
print("Visibilidad B1200_Vo =",B1200_Vo)
print("ok Baseline 1200mm")
# Out:
# ('Visibilidad B1200_vo1 =', 0.1271393773431133)
# ('Visibilidad B1200_vo2 =', 0.14498143907476255)
# ('Visibilidad B1200_vo3 =', 0.10506798793751591)
# ('Visibilidad B1200_Vo =', 0.12572960145179726)
# ok Baseline 1200mm

# %%
sigma_1200=math.sqrt(((((B1200_Vo1-B1200_Vo)**2+(B1200_Vo2-B1200_Vo)**2+(B1200_Vo3-B1200_Vo)**2))/2))
sigma_1200
# Out:
# 0.019994036522652088

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B1300.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(26,93)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.05,0.16))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 1300 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B1300.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B1300.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(82,83)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.05,0.095))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 1300 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B1300-Z3.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
#Sample_1 at 60.1 segundos
B1300_Pmax_1 = 0.092437498
B1300_Pmin_1 = 0.071625002
B1300_Vo1 = (B1300_Pmax_1-B1300_Pmin_1)/(B1300_Pmax_1+B1300_Pmin_1)

#Sample_2 at 79 segundos
B1300_Pmax_2 = 0.091875002
B1300_Pmin_2 = 0.06825

B1300_Vo2 = (B1300_Pmax_2-B1300_Pmin_2)/(B1300_Pmax_2+B1300_Pmin_2)

#Sample_3 at 82.5 segundos
B1300_Pmax_3 = 0.090374999
B1300_Pmin_3 = 0.068625003
B1300_Vo3 = (B1300_Pmax_3-B1300_Pmin_3)/(B1300_Pmax_3+B1300_Pmin_3)

print("Visibilidad B1300_vo1 =",B1300_Vo1)
print("Visibilidad B1300_vo2 =",B1300_Vo2)
print("Visibilidad B1300_vo3 =",B1300_Vo3)

#Valor Promedio
B1300_Vo = (B1300_Vo1+B1300_Vo2+B1300_Vo3)/3
print("Visibilidad B1300_Vo =",B1300_Vo)
print("ok Baseline 1300mm")
# Out:
# ('Visibilidad B1300_vo1 =', 0.12685711847619055)
# ('Visibilidad B1300_vo2 =', 0.1475409942539766)
# ('Visibilidad B1300_vo3 =', 0.1367924259522965)
# ('Visibilidad B1300_Vo =', 0.13706351289415453)
# ok Baseline 1300mm

# %%
sigma_1300=math.sqrt(((((B1300_Vo1-B1300_Vo)**2+(B1300_Vo2-B1300_Vo)**2+(B1300_Vo3-B1300_Vo)**2))/2))
sigma_1300
# Out:
# 0.010344602234752942

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B1400.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(36,106)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.05,0.16))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 1400 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B1400.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B1400.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(72,75)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.05,0.095))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 1400 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B1400-Z3.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
#Sample_1 at 78.5 segundos
B1400_Pmax_1 = 0.0894375
B1400_Pmin_1 = 0.067312501
B1400_Vo1 = (B1400_Pmax_1-B1400_Pmin_1)/(B1400_Pmax_1+B1400_Pmin_1)

#Sample_2 at 86.06 segundos
B1400_Pmax_2 = 0.090187497
B1400_Pmin_2 = 0.068062499
B1400_Vo2 = (B1400_Pmax_2-B1400_Pmin_2)/(B1400_Pmax_2+B1400_Pmin_2)

#Sample_3 at 73.4 segundos
B1400_Pmax_3 = 0.088687502
B1400_Pmin_3 = 0.067687504
B1400_Vo3 = (B1400_Pmax_3-B1400_Pmin_3)/(B1400_Pmax_3+B1400_Pmin_3)

print("Visibilidad B1400_vo1 =",B1400_Vo1)
print("Visibilidad B1400_vo2 =",B1400_Vo2)
print("Visibilidad B1400_vo3 =",B1400_Vo3)

#Valor Promedio
B1400_Vo = (B1400_Vo1+B1400_Vo2+B1400_Vo3)/3
print("Visibilidad B1400_Vo =",B1400_Vo)
print("ok Baseline 1400mm")
# Out:
# ('Visibilidad B1400_vo1 =', 0.14114831807879866)
# ('Visibilidad B1400_vo2 =', 0.13981041743596637)
# ('Visibilidad B1400_vo3 =', 0.1342925480047624)
# ('Visibilidad B1400_Vo =', 0.13841709450650916)
# ok Baseline 1400mm

# %%
sigma_1400=math.sqrt(((((B1400_Vo1-B1400_Vo)**2+(B1400_Vo2-B1400_Vo)**2+(B1400_Vo3-B1400_Vo)**2))/2))
sigma_1400
# Out:
# 0.003634062109585668

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B1500.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(9,77)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.05,0.16))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 1500 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B1500.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B1500.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(24.5,26.5)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.05,0.095))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 1500 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B1500-Z1.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
#Sample_1 at 25.6 segundos
B1500_Pmax_1 = 0.084375001
B1500_Pmin_1 = 0.072562501

B1500_Vo1 = (B1500_Pmax_1-B1500_Pmin_1)/(B1500_Pmax_1+B1500_Pmin_1)

#Sample_2 at 46.96 segundos
B1500_Pmax_2 = 0.086062498
B1500_Pmin_2 = 0.072375
B1500_Vo2 = (B1500_Pmax_2-B1500_Pmin_2)/(B1500_Pmax_2+B1500_Pmin_2)

#Sample_3 at 64.52 segundos
B1500_Pmax_3 = 0.088124998
B1500_Pmin_3 = 0.075374998
B1500_Vo3 = (B1500_Pmax_3-B1500_Pmin_3)/(B1500_Pmax_3+B1500_Pmin_3)

print("Visibilidad B1500_vo1 =",B1500_Vo1)
print("Visibilidad B1500_vo2 =",B1500_Vo2)
print("Visibilidad B1500_vo3 =",B1500_Vo3)

#Valor Promedio
B1500_Vo = (B1500_Vo1+B1500_Vo2+B1500_Vo3)/3
print("Visibilidad B1500_Vo =",B1500_Vo)
print("ok Baseline 1500mm")
# Out:
# ('Visibilidad B1500_vo1 =', 0.07526881624508082)
# ('Visibilidad B1500_vo2 =', 0.0863905210116358)
# ('Visibilidad B1500_vo3 =', 0.07798165328395482)
# ('Visibilidad B1500_Vo =', 0.07988033018022381)
# ok Baseline 1500mm

# %%
sigma_1500=math.sqrt(((((B1500_Vo1-B1500_Vo)**2+(B1500_Vo2-B1500_Vo)**2+(B1500_Vo3-B1500_Vo)**2))/2))
sigma_1500
# Out:
# 0.005798862793334759

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B1600.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(15,60)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.05,0.16))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 1600 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B1600.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B1600.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(43,46)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.05,0.1))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 1600 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B1600-Z3.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
#Sample_1 at 29.76 segundos
B1600_Pmax_1 = 0.093937501
B1600_Pmin_1 = 0.076875001
B1600_Vo1 = (B1600_Pmax_1-B1600_Pmin_1)/(B1600_Pmax_1+B1600_Pmin_1)

#Sample_2 at 37.49 segundos
B1600_Pmax_2 = 0.0969375
B1600_Pmin_2 = 0.079125002
B1600_Vo2 = (B1600_Pmax_2-B1600_Pmin_2)/(B1600_Pmax_2+B1600_Pmin_2)

#Sample_3 at 44.4 segundos
B1600_Pmax_3 = 0.094499998
B1600_Pmin_3 = 0.076875001
B1600_Vo3 = (B1600_Pmax_3-B1600_Pmin_3)/(B1600_Pmax_3+B1600_Pmin_3)

print("Visibilidad B1600_vo1 =",B1600_Vo1)
print("Visibilidad B1600_vo2 =",B1600_Vo2)
print("Visibilidad B1600_vo3 =",B1600_Vo3)

#Valor Promedio
B1600_Vo = (B1600_Vo1+B1600_Vo2+B1600_Vo3)/3
print("Visibilidad B1600_Vo =",B1600_Vo)
print("ok Baseline 1600mm")
# Out:
# ('Visibilidad B1600_vo1 =', 0.0998902293463274)
# ('Visibilidad B1600_vo2 =', 0.10117144649006518)
# ('Visibilidad B1600_vo3 =', 0.10284462204431583)
# ('Visibilidad B1600_Vo =', 0.10130209929356947)
# ok Baseline 1600mm

# %%
sigma_1600=math.sqrt(((((B1600_Vo1-B1600_Vo)**2+(B1600_Vo2-B1600_Vo)**2+(B1600_Vo3-B1600_Vo)**2))/2))
sigma_1600
# Out:
# 0.0014815234286974632

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B1700.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(7,72)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.05,0.16))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 1700 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B1700.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B1700.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(48,49.5)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.05,0.11))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 1700 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B1700-Z3.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
#Sample_1 at 57.3 segundos
B1700_Pmax_1 = 0.100687504
B1700_Pmin_1 = 0.085500002
B1700_Vo1 = (B1700_Pmax_1-B1700_Pmin_1)/(B1700_Pmax_1+B1700_Pmin_1)

#Sample_2 at 62.28 segundos
B1700_Pmax_2 = 0.098999999
B1700_Pmin_2 = 0.0830625
B1700_Vo2 = (B1700_Pmax_2-B1700_Pmin_2)/(B1700_Pmax_2+B1700_Pmin_2)

#Sample_3 at 48.6 segundos
B1700_Pmax_3 = 0.096187502
B1700_Pmin_3 = 0.079687499
B1700_Vo3 = (B1700_Pmax_3-B1700_Pmin_3)/(B1700_Pmax_3+B1700_Pmin_3)

print("Visibilidad B1700_vo1 =",B1700_Vo1)
print("Visibilidad B1700_vo2 =",B1700_Vo2)
print("Visibilidad B1700_vo3 =",B1700_Vo3)

#Valor Promedio
B1700_Vo = (B1700_Vo1+B1700_Vo2+B1700_Vo3)/3
print("Visibilidad B1700_Vo =",B1700_Vo)
print("ok Baseline 1700mm")
# Out:
# ('Visibilidad B1700_vo1 =', 0.08157100509203873)
# ('Visibilidad B1700_vo2 =', 0.08753861496759972)
# ('Visibilidad B1700_vo3 =', 0.09381664765420528)
# ('Visibilidad B1700_Vo =', 0.08764208923794792)
# ok Baseline 1700mm

# %%
sigma_1700=math.sqrt(((((B1700_Vo1-B1700_Vo)**2+(B1700_Vo2-B1700_Vo)**2+(B1700_Vo3-B1700_Vo)**2))/2))
sigma_1700
# Out:
# 0.006123477005227856

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B1800.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(20,76)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.05,0.16))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 1800 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B1800.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B1800.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(64,65)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.05,0.11))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 1800 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B1800-Z3.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
#Sample_1 at 59.84 segundos
B1800_Pmax_1 = 0.100500003
B1800_Pmin_1 = 0.085312501
B1800_Vo1 = (B1800_Pmax_1-B1800_Pmin_1)/(B1800_Pmax_1+B1800_Pmin_1)

#Sample_2 at 61.38 segundos
B1800_Pmax_2 = 0.099375002
B1800_Pmin_2 = 0.083999999
B1800_Vo2 = (B1800_Pmax_2-B1800_Pmin_2)/(B1800_Pmax_2+B1800_Pmin_2)

#Sample_3 at 64.60 segundos
B1800_Pmax_3 = 0.103687502
B1800_Pmin_3 = 0.085687503
B1800_Vo3 = (B1800_Pmax_3-B1800_Pmin_3)/(B1800_Pmax_3+B1800_Pmin_3)

print("Visibilidad B1800_vo1 =",B1800_Vo1)
print("Visibilidad B1800_vo2 =",B1800_Vo2)
print("Visibilidad B1800_vo3 =",B1800_Vo3)

#Valor Promedio
B1800_Vo = (B1800_Vo1+B1800_Vo2+B1800_Vo3)/3
print("Visibilidad B1800_Vo =",B1800_Vo)
print("ok Baseline 1800mm")
# Out:
# ('Visibilidad B1800_vo1 =', 0.08173562958927676)
# ('Visibilidad B1800_vo2 =', 0.08384459667978406)
# ('Visibilidad B1800_vo3 =', 0.09504949716040934)
# ('Visibilidad B1800_Vo =', 0.08687657447649005)
# ok Baseline 1800mm

# %%
sigma_1800=math.sqrt(((((B1800_Vo1-B1800_Vo)**2+(B1800_Vo2-B1800_Vo)**2+(B1800_Vo3-B1800_Vo)**2))/2))
sigma_1800
# Out:
# 0.007156076749532702

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B1900.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(50,91)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.05,0.16))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 1900 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B1900.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B1900.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(74.5,76)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.05,0.110))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 1900 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B1900-Z3.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
#Sample_1 at 53.37 segundos
B1900_Pmax_1 = 0.100874998
B1900_Pmin_1 = 0.080812499
B1900_Vo1 = (B1900_Pmax_1-B1900_Pmin_1)/(B1900_Pmax_1+B1900_Pmin_1)

#Sample_2 at 63.13 segundos
B1900_Pmax_2 = 0.099187501
B1900_Pmin_2 = 0.082500003
B1900_Vo2 = (B1900_Pmax_2-B1900_Pmin_2)/(B1900_Pmax_2+B1900_Pmin_2)

#Sample_3 at 75.31 segundos
B1900_Pmax_3 = 0.099187501
B1900_Pmin_3 = 0.081749998
B1900_Vo3 = (B1900_Pmax_3-B1900_Pmin_3)/(B1900_Pmax_3+B1900_Pmin_3)

print("Visibilidad B1900_vo1 =",B1900_Vo1)
print("Visibilidad B1900_vo2 =",B1900_Vo2)
print("Visibilidad B1900_vo3 =",B1900_Vo3)

#Valor Promedio
B1900_Vo = (B1900_Vo1+B1900_Vo2+B1900_Vo3)/3
print("Visibilidad B1900_Vo =",B1900_Vo)
print("ok Baseline 1900mm")
# Out:
# ('Visibilidad B1900_vo1 =', 0.11042311293440296)
# ('Visibilidad B1900_vo2 =', 0.09184725219187333)
# ('Visibilidad B1900_vo3 =', 0.09637307410776134)
# ('Visibilidad B1900_Vo =', 0.09954781307801254)
# ok Baseline 1900mm

# %%
sigma_1900=math.sqrt(((((B1900_Vo1-B1900_Vo)**2+(B1900_Vo2-B1900_Vo)**2+(B1900_Vo3-B1900_Vo)**2))/2))
sigma_1900
# Out:
# 0.009686324185592135

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2000.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(0,60)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.05,0.16))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 2000 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2000.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2000.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(38,39)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.05,0.110))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 2000 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2000-Z3.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
#Sample_1 at 43.53 segundos
B2000_Pmax_1 = 0.096375003
B2000_Pmin_1 = 0.082312501
B2000_Vo1 = (B2000_Pmax_1-B2000_Pmin_1)/(B2000_Pmax_1+B2000_Pmin_1)

#Sample_2 at 48.35 segundos
B2000_Pmax_2 = 0.097500004
B2000_Pmin_2 = 0.082500003
B2000_Vo2 = (B2000_Pmax_2-B2000_Pmin_2)/(B2000_Pmax_2+B2000_Pmin_2)

#Sample_3 at 38.5 segundos
B2000_Pmax_3 = 0.105374999
B2000_Pmin_3 = 0.091499998
B2000_Vo3 = (B2000_Pmax_3-B2000_Pmin_3)/(B2000_Pmax_3+B2000_Pmin_3)

print("Visibilidad B2000_vo1 =",B2000_Vo1)
print("Visibilidad B2000_vo2 =",B2000_Vo2)
print("Visibilidad B2000_vo3 =",B2000_Vo3)

#Valor Promedio
B2000_Vo = (B2000_Vo1+B2000_Vo2+B2000_Vo3)/3
print("Visibilidad B2000_Vo =",B2000_Vo)
print("ok Baseline 2000mm")
# Out:
# ('Visibilidad B2000_vo1 =', 0.07869885518127784)
# ('Visibilidad B2000_vo2 =', 0.08333333564814804)
# ('Visibilidad B2000_vo3 =', 0.07047619662947854)
# ('Visibilidad B2000_Vo =', 0.0775027958196348)
# ok Baseline 2000mm

# %%
sigma_2000=math.sqrt(((((B2000_Vo1-B2000_Vo)**2+(B2000_Vo2-B2000_Vo)**2+(B2000_Vo3-B2000_Vo)**2))/2))
sigma_2000
# Out:
# 0.006511484042350014

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2100.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(20,75)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.05,0.16))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 2100 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2000.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2100.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(36,38)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.05,0.10))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 2100 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2100-Z3.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
#Sample_1 at  segundos
B2100_Pmax_1 = 0.096375003
B2100_Pmin_1 = 0.081562504
B2100_Vo1 = (B2100_Pmax_1-B2100_Pmin_1)/(B2100_Pmax_1+B2100_Pmin_1)

#Sample_2 at 62.8 segundos
B2100_Pmax_2 = 0.094875
B2100_Pmin_2 = 0.080624998
B2100_Vo2 = (B2100_Pmax_2-B2100_Pmin_2)/(B2100_Pmax_2+B2100_Pmin_2)

#Sample_3 at 37.12 segundos
B2100_Pmax_3 = 0.087375
B2100_Pmin_3 = 0.078375004
B2100_Vo3 = (B2100_Pmax_3-B2100_Pmin_3)/(B2100_Pmax_3+B2100_Pmin_3)

print("Visibilidad B2100_vo1 =",B2100_Vo1)
print("Visibilidad B2100_vo2 =",B2100_Vo2)
print("Visibilidad B2100_vo3 =",B2100_Vo3)

#Valor Promedio
B2100_Vo = (B2100_Vo1+B2100_Vo2+B2100_Vo3)/3
print("Visibilidad B2100_Vo =",B2100_Vo)
print("ok Baseline 2100mm")
# Out:
# ('Visibilidad B2100_vo1 =', 0.08324551270688539)
# ('Visibilidad B2100_vo2 =', 0.08119659351790989)
# ('Visibilidad B2100_vo3 =', 0.054298617090832745)
# ('Visibilidad B2100_Vo =', 0.07291357443854267)
# ok Baseline 2100mm

# %%
sigma_2100=math.sqrt(((((B2100_Vo1-B2100_Vo)**2+(B2100_Vo2-B2100_Vo)**2+(B2100_Vo3-B2100_Vo)**2))/2))
sigma_2100
# Out:
# 0.016153544355760843

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2200.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(19,100)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.05,0.16))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 2200 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2200.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2200.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(70,72)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.05,0.10))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 2200 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2200-Z3.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
#Sample_1 at 81.6 segundos
B2200_Pmax_1 = 0.086062498
B2200_Pmin_1 = 0.073875003
B2200_Vo1 = (B2200_Pmax_1-B2200_Pmin_1)/(B2200_Pmax_1+B2200_Pmin_1)

#Sample_2 at 87.8 segundos
B2200_Pmax_2 = 0.090000004
B2200_Pmin_2 = 0.078562498
B2200_Vo2 = (B2200_Pmax_2-B2200_Pmin_2)/(B2200_Pmax_2+B2200_Pmin_2)

#Sample_3 at 71.125 segundos
B2200_Pmax_3 = 0.089812502
B2200_Pmin_3 = 0.080624998
B2200_Vo3 = (B2200_Pmax_3-B2200_Pmin_3)/(B2200_Pmax_3+B2200_Pmin_3)

print("Visibilidad B2200_vo1 =",B2200_Vo1)
print("Visibilidad B2200_vo2 =",B2200_Vo2)
print("Visibilidad B2200_vo3 =",B2200_Vo3)

#Valor Promedio
B2200_Vo = (B2200_Vo1+B2200_Vo2+B2200_Vo3)/3
print("Visibilidad B2200_Vo =",B2200_Vo)
print("ok Baseline 2200mm")
# Out:
# ('Visibilidad B2200_vo1 =', 0.07620160952746166)
# ('Visibilidad B2200_vo2 =', 0.067853204979124)
# ('Visibilidad B2200_vo3 =', 0.05390541400806746)
# ('Visibilidad B2200_Vo =', 0.0659867428382177)
# ok Baseline 2200mm

# %%
sigma_2200=math.sqrt(((((B2200_Vo1-B2200_Vo)**2+(B2200_Vo2-B2200_Vo)**2+(B2200_Vo3-B2200_Vo)**2))/2))
sigma_2200
# Out:
# 0.011264672403241067

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2300.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(4,112)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.05,0.16))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 2300 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2300.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2300.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(59,61)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.06,0.1))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 2300 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2300-Z2.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
#Sample_1 at 54.57 segundos
B2300_Pmax_1 = 0.088500001
B2300_Pmin_1 = 0.080624998
B2300_Vo1 = (B2300_Pmax_1-B2300_Pmin_1)/(B2300_Pmax_1+B2300_Pmin_1)

#Sample_2 at 60.05 segundos
B2300_Pmax_2 = 0.0905625
B2300_Pmin_2 = 0.081937499
B2300_Vo2 = (B2300_Pmax_2-B2300_Pmin_2)/(B2300_Pmax_2+B2300_Pmin_2)

#Sample_3 at 46.49 segundos
B2300_Pmax_3 = 1
B2300_Pmin_3 = 1
B2300_Vo3 = (B2300_Pmax_3-B2300_Pmin_3)/(B2300_Pmax_3+B2300_Pmin_3)

print("Visibilidad B2300_vo1 =",B2300_Vo1)
print("Visibilidad B2300_vo2 =",B2300_Vo2)
print("Visibilidad B2300_vo3 =",B2300_Vo3)

#Valor Promedio
B2300_Vo = (B2300_Vo1+B2300_Vo2+B2300_Vo3)/2
print("Visibilidad B2300_Vo =",B2300_Vo)
print("ok Baseline 2300mm")
# Out:
# ('Visibilidad B2300_vo1 =', 0.04656321091833379)
# ('Visibilidad B2300_vo2 =', 0.050000006086956594)
# ('Visibilidad B2300_vo3 =', 0)
# ('Visibilidad B2300_Vo =', 0.04828160850264519)
# ok Baseline 2300mm

# %%
sigma_2300=math.sqrt(((((B2300_Vo1-B2300_Vo)**2+(B2300_Vo2-B2300_Vo)**2))/1))
sigma_2300
# Out:
# 0.0024301811692823477

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2400.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(3,55)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.05,0.12))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 2400 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2400.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2400.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(46,47)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.05,0.10))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 2400 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2400-Z3.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
#Sample_1 at 27.3 segundos
B2400_Pmax_1 = 0.094125003
B2400_Pmin_1 = 0.082874998
B2400_Vo1 = (B2400_Pmax_1-B2400_Pmin_1)/(B2400_Pmax_1+B2400_Pmin_1)

#Sample_2 at 38.48 segundos
B2400_Pmax_2 = 0.092812501
B2400_Pmin_2 = 0.082312502
B2400_Vo2 = (B2400_Pmax_2-B2400_Pmin_2)/(B2400_Pmax_2+B2400_Pmin_2)

#Sample_3 at 46.47 segundos
B2400_Pmax_3 = 0.092812501
B2400_Pmin_3 = 0.081562504

B2400_Vo3 = (B2400_Pmax_3-B2400_Pmin_3)/(B2400_Pmax_3+B2400_Pmin_3)

print("Visibilidad B2400_vo1 =",B2400_Vo1)
print("Visibilidad B2400_vo2 =",B2400_Vo2)
print("Visibilidad B2400_vo3 =",B2400_Vo3)

#Valor Promedio
B2400_Vo = (B2400_Vo1+B2400_Vo2+B2400_Vo3)/3
print("Visibilidad B2400_Vo =",B2400_Vo)
print("ok Baseline 2400mm")
# Out:
# ('Visibilidad B2400_vo1 =', 0.06355934992339346)
# ('Visibilidad B2400_vo2 =', 0.059957166710227036)
# ('Visibilidad B2400_vo3 =', 0.06451610997803275)
# ('Visibilidad B2400_Vo =', 0.06267754220388443)
# ok Baseline 2400mm

# %%
sigma_2400=math.sqrt(((((B2400_Vo1-B2400_Vo)**2+(B2400_Vo2-B2400_Vo)**2+(B2400_Vo3-B2400_Vo)**2))/2))
sigma_2400
# Out:
# 0.002403992423117651

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2500.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(12,78)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.05,0.12))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 2500 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2500.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2500.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(58.5,60)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.05,0.09))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 2500 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2500-Z3.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
#Sample_1 at 29.79 segundos
B2500_Pmax_1 = 0.091312498
B2500_Pmin_1 = 0.081749998
B2500_Vo1 = (B2500_Pmax_1-B2500_Pmin_1)/(B2500_Pmax_1+B2500_Pmin_1)

#Sample_2 at 33.51 segundos
B2500_Pmax_2 = 0.090750001
B2500_Pmin_2 = 0.081937499
B2500_Vo2 = (B2500_Pmax_2-B2500_Pmin_2)/(B2500_Pmax_2+B2500_Pmin_2)

#Sample_3 at 59.17 segundos
B2500_Pmax_3 = 0.087937504
B2500_Pmin_3 = 0.081187502
B2500_Vo3 = (B2500_Pmax_3-B2500_Pmin_3)/(B2500_Pmax_3+B2500_Pmin_3)

print("Visibilidad B2500_vo1 =",B2500_Vo1)
print("Visibilidad B2500_vo2 =",B2500_Vo2)
print("Visibilidad B2500_vo3 =",B2500_Vo3)

#Valor Promedio
B2500_Vo = (B2500_Vo1+B2500_Vo2+B2500_Vo3)/3
print("Visibilidad B2500_Vo =",B2500_Vo)
print("ok Baseline 2500mm")
# Out:
# ('Visibilidad B2500_vo1 =', 0.055254605827480964)
# ('Visibilidad B2500_vo2 =', 0.051031499095186394)
# ('Visibilidad B2500_vo3 =', 0.039911318613641354)
# ('Visibilidad B2500_Vo =', 0.04873247451210291)
# ok Baseline 2500mm

# %%
sigma_2500=math.sqrt(((((B2500_Vo1-B2500_Vo)**2+(B2500_Vo2-B2500_Vo)**2+(B2500_Vo3-B2500_Vo)**2))/2))
sigma_2500
# Out:
# 0.00792579656292099

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2600.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(4,58)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.05,0.12))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 2600 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2600.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2600.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(19,20.5)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.05,0.1))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 2600 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2600-Z2.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
#Sample_1 at 15.5 segundos
B2600_Pmax_1 = 0.090937503
B2600_Pmin_1 = 0.082687497
B2600_Vo1 = (B2600_Pmax_1-B2600_Pmin_1)/(B2600_Pmax_1+B2600_Pmin_1)

#Sample_2 at 19.48 segundos
B2600_Pmax_2 = 0.089625001
B2600_Pmin_2 = 0.081375003
B2600_Vo2 = (B2600_Pmax_2-B2600_Pmin_2)/(B2600_Pmax_2+B2600_Pmin_2)

#Sample_3 at 22.8 segundos
B2600_Pmax_3 = 0.089812502
B2600_Pmin_3 = 0.082312502 
B2600_Vo3 = (B2600_Pmax_3-B2600_Pmin_3)/(B2600_Pmax_3+B2600_Pmin_3)

print("Visibilidad B2600_vo1 =",B2600_Vo1)
print("Visibilidad B2600_vo2 =",B2600_Vo2)
print("Visibilidad B2600_vo3 =",B2600_Vo3)

#Valor Promedio
B2600_Vo = (B2600_Vo1+B2600_Vo2+B2600_Vo3)/3
print("Visibilidad B2600_Vo =",B2600_Vo)
print("ok Baseline 2600mm")
# Out:
# ('Visibilidad B2600_vo1 =', 0.047516233261339115)
# ('Visibilidad B2600_vo2 =', 0.04824560121062919)
# ('Visibilidad B2600_vo3 =', 0.043572983736866064)
# ('Visibilidad B2600_Vo =', 0.046444939402944786)
# ok Baseline 2600mm

# %%
sigma_2600=math.sqrt(((((B2600_Vo1-B2600_Vo)**2+(B2600_Vo2-B2600_Vo)**2+(B2600_Vo3-B2600_Vo)**2))/2))
sigma_2600
# Out:
# 0.002513780303110073

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2700.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(10,90)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.05,0.1))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 2700 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2700.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2700.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(61,64)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.05,0.1))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 2700 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2700-Z2.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
#Sample_1 at 55.86  segundos
B2700_Pmax_1 = 0.086812504
B2700_Pmin_1 = 0.078749999
B2700_Vo1 = (B2700_Pmax_1-B2700_Pmin_1)/(B2700_Pmax_1+B2700_Pmin_1)

#Sample_2 at 62.71 segundos
B2700_Pmax_2 = 0.086437501
B2700_Pmin_2 = 0.079499997
B2700_Vo2 = (B2700_Pmax_2-B2700_Pmin_2)/(B2700_Pmax_2+B2700_Pmin_2)

#Sample_3 at  segundos 0.0919314  0.0867914
B2700_Pmax_3 = 1
B2700_Pmin_3 = 1 
B2700_Vo3 = (B2700_Pmax_3-B2700_Pmin_3)/(B2700_Pmax_3+B2700_Pmin_3)

print("Visibilidad B2700_vo1 =",B2700_Vo1)
print("Visibilidad B2700_vo2 =",B2700_Vo2)
print("Visibilidad B2700_vo3 =",B2700_Vo3)

#Valor Promedio
B2700_Vo = (B2700_Vo1+B2700_Vo2+B2700_Vo3)/2
print("Visibilidad B2700_Vo =",B2700_Vo)
print("ok Baseline 2700mm")
# Out:
# ('Visibilidad B2700_vo1 =', 0.0486976510617262)
# ('Visibilidad B2700_vo2 =', 0.04180793421388092)
# ('Visibilidad B2700_vo3 =', 0)
# ('Visibilidad B2700_Vo =', 0.04525279263780356)
# ok Baseline 2700mm

# %%
sigma_2700=math.sqrt(((((B2700_Vo1-B2700_Vo)**2+(B2700_Vo2-B2700_Vo)**2))/1))
sigma_2700
# Out:
# 0.004871765503566605

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2800.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(9,84)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.05,0.1))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 2800 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2800.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2800.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(52,58)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.06,0.1))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 2800 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2800-Z3.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
#Sample_1 at 29.42 segundos
B2800_Pmax_1 = 0.090187497
B2800_Pmin_1 = 0.081375003
B2800_Vo1 = (B2800_Pmax_1-B2800_Pmin_1)/(B2800_Pmax_1+B2800_Pmin_1)

#Sample_2 at 49.31 segundos
B2800_Pmax_2 = 0.091312498
B2800_Pmin_2 = 0.078749999
B2800_Vo2 = (B2800_Pmax_2-B2800_Pmin_2)/(B2800_Pmax_2+B2800_Pmin_2)

#Sample_3 at 55.49 segundos
B2800_Pmax_3 = 0.089249998
B2800_Pmin_3 = 0.080062501
B2800_Vo3 = (B2800_Pmax_3-B2800_Pmin_3)/(B2800_Pmax_3+B2800_Pmin_3)

print("Visibilidad B2800_vo1 =",B2800_Vo1)
print("Visibilidad B2800_vo2 =",B2800_Vo2)
print("Visibilidad B2800_vo3 =",B2800_Vo3)

#Valor Promedio
B2800_Vo = (B2800_Vo1+B2800_Vo2+B2800_Vo3)/3
print("Visibilidad B2800_Vo =",B2800_Vo)
print("ok Baseline 2800mm")
# Out:
# ('Visibilidad B2800_vo1 =', 0.05136608524590166)
# ('Visibilidad B2800_vo2 =', 0.07386989619469132)
# ('Visibilidad B2800_vo3 =', 0.05426354849325095)
# ('Visibilidad B2800_Vo =', 0.05983317664461465)
# ok Baseline 2800mm

# %%
sigma_2800=math.sqrt(((((B2800_Vo1-B2800_Vo)**2+(B2800_Vo2-B2800_Vo)**2+(B2800_Vo3-B2800_Vo)**2))/2))
sigma_2800
# Out:
# 0.012242178936490987

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2900.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(4,60)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.05,0.1))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 2900 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2900.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2900.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(49,50)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.07,0.09))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 2900 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B2900-Z2.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
#Sample_1 at 29.68 segundos
B2900_Pmax_1 = 0.087750003
B2900_Pmin_1 = 0.079312503
B2900_Vo1 = (B2900_Pmax_1-B2900_Pmin_1)/(B2900_Pmax_1+B2900_Pmin_1)

#Sample_2 at 49.31 segundos
B2900_Pmax_2 = 0.088500001
B2900_Pmin_2 = 0.081
B2900_Vo2 = (B2900_Pmax_2-B2900_Pmin_2)/(B2900_Pmax_2+B2900_Pmin_2)

#Sample_3 at segundos
B2900_Pmax_3 = 1
B2900_Pmin_3 = 1
B2900_Vo3 = (B2900_Pmax_3-B2900_Pmin_3)/(B2900_Pmax_3+B2900_Pmin_3)

print("Visibilidad B2900_vo1 =",B2900_Vo1)
print("Visibilidad B2900_vo2 =",B2900_Vo2)
print("Visibilidad B2900_vo3 =",B2900_Vo3)

#Valor Promedio
B2900_Vo = (B2900_Vo1+B2900_Vo2+B2900_Vo3)/2
print("Visibilidad B2900_Vo =",B2900_Vo)
print("ok Baseline 2900mm")
# Out:
# ('Visibilidad B2900_vo1 =', 0.05050504869117662)
# ('Visibilidad B2900_vo2 =', 0.04424779324927551)
# ('Visibilidad B2900_vo3 =', 0)
# ('Visibilidad B2900_Vo =', 0.04737642097022607)
# ok Baseline 2900mm

# %%
sigma_2900=math.sqrt(((((B2900_Vo1-B2900_Vo)**2+(B2900_Vo2-B2900_Vo)**2))/1))
sigma_2900
# Out:
# 0.004424547754584701

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B3000.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(20,60)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.05,0.1))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 3000 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B3000.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
data1=np.loadtxt('/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B3000.log')
mpl.rcParams['figure.figsize'] = [15, 5]
plt.grid(True)

plt.plot(data1[:,0],data1[:,1]*-1,'none', linewidth=1.5, color='#1f77b4',)
pl.xlim(49,50)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0.06,0.1))
plt.yticks(fontsize=14, rotation=0)
plt.title('IMFR11GHz Interference fringes at Baseline 3000 mm', size=20)
plt.xlabel('Time (s)', size=20)
plt.ylabel('Intensity', size=20)
plt.grid(True)
#filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-B3000-Z1.jpg'
#plt.savefig(filename, dpi = 300)
plt.show()

# %%
#Sample_1 at  segundos
B3000_Pmax_1 = 
B3000_Pmin_1 = 
B3000_Vo1 = (B3000_Pmax_1-B3000_Pmin_1)/(B3000_Pmax_1+B3000_Pmin_1)

#Sample_2 at  segundos
B3000_Pmax_2 = 
B3000_Pmin_2 = 
B3000_Vo2 = (B3000_Pmax_2-B3000_Pmin_2)/(B3000_Pmax_2+B3000_Pmin_2)

#Sample_3 at segundos
B3000_Pmax_3 = 
B3000_Pmin_3 = 
B3000_Vo3 = (B3000_Pmax_3-B3000_Pmin_3)/(B3000_Pmax_3+B3000_Pmin_3)

print("Visibilidad B3000_vo1 =",B3000_Vo1)
print("Visibilidad B3000_vo2 =",B3000_Vo2)
print("Visibilidad B3000_vo3 =",B3000_Vo3)

#Valor Promedio
B3000_Vo = (B3000_Vo1+B3000_Vo2+B3000_Vo3)/2
print("Visibilidad B3000_Vo =",B3000_Vo)
print("ok Baseline 3000mm")
# Out:
#   File "<ipython-input-120-134df808e0d4>", line 2
#     B3000_Pmax_1 =
#                    ^
# SyntaxError: invalid syntax

# %%
sigma_3000=math.sqrt(((((B3000_Vo1-B3000_Vo)**2+(B3000_Vo2-B3000_Vo)**2+(B3000_Vo3-B3000_Vo)**2))/2))
sigma_3000
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-121-c21247028c20> in <module>()
# ----> 1 sigma_3000=math.sqrt(((((B3000_Vo1-B3000_Vo)**2+(B3000_Vo2-B3000_Vo)**2+(B3000_Vo3-B3000_Vo)**2))/2))
#       2 sigma_3000
#
# NameError: name 'B3000_Vo1' is not defined

# %% [markdown]
# # VISIBILIDAD vs B_lambda

# %%
B_lambda
# Out:
# array([  34.49052744,   40.36125552,   44.03046057,   47.69966561,
#          51.36887066,   55.03807571,   58.70728075,   62.3764858 ,
#          66.04569085,   69.7148959 ,   73.38410094,   77.05330599,
#          80.72251104,   84.39171609,   88.06092113,   91.73012618,
#          95.39933123,   99.06853627,  102.73774132,  106.40694637])

# %%
Vo_data = np.array([B940_Vo, B1100_Vo, B1200_Vo, B1300_Vo, B1400_Vo, B1500_Vo, B1600_Vo, B1700_Vo, B1800_Vo, B1900_Vo, B2000_Vo, B2100_Vo, B2200_Vo, B2300_Vo, B2400_Vo, B2500_Vo, B2600_Vo, B2700_Vo, B2800_Vo, B2900_Vo])

# %%
Vo_data
# Out:
# array([ 0.368605  ,  0.08886063,  0.1257296 ,  0.13706351,  0.13841709,
#         0.07988033,  0.1013021 ,  0.08764209,  0.08687657,  0.09954781,
#         0.0775028 ,  0.07291357,  0.06598674,  0.04828161,  0.06267754,
#         0.04873247,  0.04644494,  0.04525279,  0.05983318,  0.04737642])

# %%
Err_data = np.array([sigma_940, sigma_1100, sigma_1200, sigma_1300, sigma_1400, sigma_1500, sigma_1600, sigma_1700, sigma_1800, sigma_1900, sigma_2000, sigma_2100, sigma_2200, sigma_2300, sigma_2400, sigma_2500, sigma_2600, sigma_2700, sigma_2800, sigma_2900 ])
Err_data
# Out:
# array([ 0.02111273,  0.01665262,  0.01999404,  0.0103446 ,  0.00363406,
#         0.00579886,  0.00148152,  0.00612348,  0.00715608,  0.00968632,
#         0.00651148,  0.01615354,  0.01126467,  0.00243018,  0.00240399,
#         0.0079258 ,  0.00251378,  0.00487177,  0.01224218,  0.00442455])

# %%
plt.plot(B_lambda, Vo_data, marker='o', color='black', linewidth=2, linestyle='-', label='Visibilidad')
mpl.rcParams['figure.figsize'] = [10, 5]
plt.errorbar([B_lambda], [Vo_data], xerr=0, yerr=[Err_data],fmt='o', color='red',
             ecolor='navy', elinewidth=2, capsize=2, label="Error bars plot")
plt.legend(loc=('upper right'),fontsize=15)
pl.xlim(34,105)
plt.xticks(fontsize=14, rotation=0)
plt.ylim((0,0.5))
plt.yticks(fontsize=14, rotation=0)

plt.title('Amplitud de la visibilidad', size=20)
plt.xlabel('B_lambda', size=20)
plt.ylabel('Amplitud de la visibilidad', size=20)
plt.grid(True)
filename = '/home/alfazoom/imfr-hal/python/Sesion24.08.2018/IMFR11GHz-24.08.2018-Visibilidad.jpg'
plt.savefig(filename, dpi = 300)
plt.grid(True)
plt.show()
